# %% [markdown]
# # YASH HAJARE

# %% [markdown]
# # Task 3:- To Explore Decision Tree Algorithm on Iris Dataset
# To create the decision tree classifier and visualizing it

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/Yash/Downloads/Iris.csv')

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Checking the first five rows

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # Checking column datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.3+ KB

# %% [markdown]
# # Checking important statistics parametes

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # Plotting inter-relation of all the attributes / Exploratory Data Analysis

# %%
sns.pairplot(df,hue='Species',palette='plasma')

# %%
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',hue='Species',data=df)

# %%
sns.scatterplot(x='PetalLengthCm',y='PetalWidthCm',hue='Species',data=df)

# %%
sns.countplot(df['Species'])

# %% [markdown]
# # Creating test and train datasets

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('Species',axis=1)
y=df['Species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# # Importing Decision Tree Classifier from Scikit Learn, fitting and predicting the values

# %%
from sklearn.tree import DecisionTreeClassifier
tree=DecisionTreeClassifier()
tree.fit(X_train,y_train)
predic=tree.predict(X_test)
print("Decision Tree is ready")
# Out:
# Decision Tree is ready

# %% [markdown]
# # Developing Classification Report

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,predic))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        11
# Iris-versicolor       0.88      0.78      0.82         9
#  Iris-virginica       0.82      0.90      0.86        10
#
#        accuracy                           0.90        30
#       macro avg       0.90      0.89      0.89        30
#    weighted avg       0.90      0.90      0.90        30

# %% [markdown]
# # Developing Confusion Matrix

# %%
print(confusion_matrix(y_test,predic))
# Out:
# [[11  0  0]
#  [ 0  7  2]
#  [ 0  1  9]]

# %% [markdown]
# # Importing accuracy score

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Calculating accuracy of model

# %%
print(accuracy_score(y_test,predic))
# Out:
# 0.9

# %% [markdown]
# # Installing libraries for visualization task

# %%
# !pip install pydotplus
# !pip install graphviz
# Out:
# Requirement already satisfied: pydotplus in c:\users\yash\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\yash\anaconda3\lib\site-packages (from pydotplus) (2.4.7)
# Requirement already satisfied: graphviz in c:\users\yash\anaconda3\lib\site-packages (0.14.2)

# %% [markdown]
# # Importing tools for tree visualization

# %%
from six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# %% [markdown]
# # Visualization of tree classifier

# %%
dot_data = StringIO()
export_graphviz(tree, out_file=dot_data, feature_names=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],
                filled=True, rounded=True,special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
